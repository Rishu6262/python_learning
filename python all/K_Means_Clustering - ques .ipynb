# %% [markdown]
# # K-Means Clustering — Mall Customer Segmentation

# %% [markdown]
# 1. Importing Required Libraries

# %% [markdown]
# 📂 2. Loading the Dataset

# %% [markdown]
# 🔍 3. Basic Information About the Dataset

# %% [markdown]
# 📊 4. Exploratory Data Analysis (EDA)

# %% [markdown]
# 4.1 Gender Distribution

# %% [markdown]
# 4.2 Age Distribution

# %% [markdown]
# 4.3 Annual Income Distribution

# %% [markdown]
# 4.4 Spending Score Distribution

# %% [markdown]
# 4.5 Pairplot (Visual Relation)

# %% [markdown]
# 4.6 Income vs Spending Score

# %% [markdown]
# 🧩 5. Data Preprocessing
#
# We’ll use only the numeric columns (Age, Annual Income, Spending Score) for clustering.

# %% [markdown]
# ⚙️ 6. Finding Optimal Number of Clusters (K)

# %% [markdown]
# We’ll use the Elbow Method now.
#
# (Silhouette Score can also be used to validate K — we’ll learn this in future.)

# %% [markdown]
# How to choose K: Look for the bend (elbow) where WCSS stops dropping sharply (commonly K = 4 or 5 for this dataset).

# %% [markdown]
# 🧠 7. Building the Final K-Means Model

# %% [markdown]
# 📈 8. Visualizing the Clusters (2D)
#
# We’ll visualize Annual Income vs Spending Score with cluster coloring.

# %% [markdown]
# 🎨 9. Visualize Cluster Centers

# %% [markdown]
# 💾 10. Saving Results
