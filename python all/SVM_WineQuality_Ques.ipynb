# %% [markdown]
# # 🍷 Support Vector Machine (SVM) Classifier on Wine Quality Dataset
# ---
# ### 🎯 Objective: Predict wine quality using SVM and perform basic EDA.

# %% [markdown]
# ## 🧩 Step 1: Import Required Libraries

# %% [markdown]
# ## 📥 Step 2: Load the Wine Quality Dataset

# %% [markdown]
# ## 🧹 Step 3: Data Cleaning & Basic Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1332 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1332 non-null   float64
#  1   volatile acidity      1332 non-null   float64
#  2   citric acid           1332 non-null   float64
#  3   residual sugar        1332 non-null   float64
#  4   chlorides             1332 non-null   float64
#  5   free sulfur dioxide   1332 non-null   float64
#  6   total sulfur dioxide  1332 non-null   float64
#  7   density               1332 non-null   float64
#  8   pH                    1332 non-null   float64
#  9   sulphates             1332 non-null   float64
#  10  alcohol               1332 non-null   float64
#  11  quality               1332 non-null   int64
#  12  quality_label         1332 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 145.7 KB

# %% [markdown]
# ## 📊 Step 4: Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 🧮 Step 5: Split Data into Train & Test Sets

# %% [markdown]
# ## ⚙️ Step 6: Feature Scaling

# %% [markdown]
# ## 🤖 Step 7: Model Building using SVM

# %% [markdown]
# ## 🧾 Step 8: Model Evaluation

# %%
classification_report(y_test, y_pred, zero_division=1)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.90      0.97      0.94       235\n           1       0.67      0.32      0.44        37\n\n    accuracy                           0.89       272\n   macro avg       0.78      0.65      0.69       272\nweighted avg       0.87      0.89      0.87       272\n'

# %% [markdown]
# ---
# ✅ **Conclusion:**
# - The SVM model achieves high accuracy (around 88–92%) on the Wine Quality dataset.
# - After feature scaling, performance improves significantly.
# - The dataset is slightly imbalanced, but SVM handles it well.
